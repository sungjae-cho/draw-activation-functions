# %%
import numpy as np
import matplotlib.pyplot as plt
import activation_function as af

# %%
x = np.arange(-1.5, 1.5, 0.01)
y1 = af.linear(x)
y2 = af.binary_threshold(x)
y3 = af.sigmoid(x)
y4 = af.tanh(x)
y5 = af.relu(x)

# %%
plt.figure(1)

# %%
plt.plot(x, y1, 'c',
        x, y2, 'g',
        x, y3, 'b',
        x, y4, 'r',
        x, y5, 'm')
# Out:
# [<matplotlib.lines.Line2D at 0x7c1a080>,
#  <matplotlib.lines.Line2D at 0x7c1a240>,
#  <matplotlib.lines.Line2D at 0x7b3a4e0>,
#  <matplotlib.lines.Line2D at 0x7b2a7b8>,
#  <matplotlib.lines.Line2D at 0x7b1e278>]

# %%
plt.title('Activation Functions')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)

# %%
plt.show()

# %% [markdown]
# # Generalization of the interval

# %%
import numpy as np
import matplotlib.pyplot as plt
import activation_function as af

def af_plot(begin, end):
    # %matplotlib inline 
    x = np.arange(begin, end, 0.01)
    y1 = af.linear(x)
    y2 = af.binary_threshold(x)
    y3 = af.sigmoid(x)
    y4 = af.tanh(x)
    y5 = af.relu(x)
    
    plt.figure(1)
    
    plt.plot(x, y1, 'c',
            x, y2, 'g',
            x, y3, 'b',
            x, y4, 'r',
            x, y5, 'm')
    
    plt.title('Activation Functions')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.grid(True)
    
    plt.show()

# %% [markdown]
# # 1. Interval [-1, 1]

# %%
af_plot(-1,1)

# %%
plt.savefig('af_1')

# %% [markdown]
# # 2. Interval [-1, 1]

# %%
af_plot(-2,2)

# %% [markdown]
# # 3. Interval [-5, 5]

# %%
af_plot(-5,5)

# %% [markdown]
# # 4. Interval [-10, 10]

# %%
af_plot(-10,10)
